# %% [markdown]
# `Pair Programming ETL I extracción`

# %% [markdown]
# Vamos a nutrir los datos de los ataques de los tiburones con información climática de los paises que tenemos. Para eso vamos a usar la API del clima que hemos aprendido en la clase invertida:
# url = f'http://www.7timer.info/bin/api.pl?lon=-{lon}&lat={lat}&product={producto}&output=json'
#
# Requisitos de este ejercicio de pair programming:
# Deberéis meter toda la información climática en un único dataframe.

# %%
from IPython.core.interactiveshell import InteractiveShell # Nos permite mostar más de una salida por celda
InteractiveShell.ast_node_interactivity = "all" # Nos permite mostar más de una salida por celda

import requests
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# Deberéis hacer la llamada a la API de una sola vez. Es decir, tendréis que iterar por la lista de países y sacar la información del clima para cada uno de ellos.

# %%
dicc= {'usa': [39.7837304, -100.445882], 'australia': [-24.7761086,  134.755], 'south africa': [-28.8166236, 24.991639], 'new zealand': [-41.5000831, 172.8344077], 'papua new guinea':[-5.6816069, 144.2489081] }

# %%
df_todo = pd.DataFrame()
for k, v in dicc.items():
    url =  f'http://www.7timer.info/bin/api.pl?lon={v[1]}5&lat=-{v[0]}6&product=meteo&output=json'
    response=requests.get(url=url)
    df = pd.json_normalize(response.json()['dataseries'])
    df["country"] = k
    df_todo = pd.concat([df, df_todo], axis = 0)

# %%
df_todo=df_todo.rename(columns={'wind10m.direction': 'wind10m_direction',
               'wind10m.speed': 'wind10m_speed'})

# %%
df_todo
# Out:
#     timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0           3           9      -9999     -9999     -9999
# 1           6           9      -9999     -9999     -9999
# 2           9           9      -9999     -9999     -9999
# 3          12           9      -9999     -9999     -9999
# 4          15           9      -9999     -9999     -9999
# ..        ...         ...        ...       ...       ...
# 59        180           2      -9999     -9999     -9999
# 60        183           1      -9999     -9999     -9999
# 61        186           1      -9999     -9999     -9999
# 62        189           1      -9999     -9999     -9999
# 63        192           1      -9999     -9999     -9999
#
#                                            rh_profile  \
# 0   [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1   [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 2   [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 3   [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 4   [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# ..                                                ...
# 59  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 60  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 61  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 62  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 63  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
#
#                                          wind_profile  temp2m  lifted_index  \
# 0   [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1   [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
# 2   [{'layer': '950mb', 'direction': 120, 'speed':...      29            -4
# 3   [{'layer': '950mb', 'direction': 125, 'speed':...      29            -4
# 4   [{'layer': '950mb', 'direction': 120, 'speed':...      28            -4
# ..                                                ...     ...           ...
# 59  [{'layer': '950mb', 'direction': 265, 'speed':...      10             6
# 60  [{'layer': '950mb', 'direction': 275, 'speed':...      10             6
# 61  [{'layer': '950mb', 'direction': 275, 'speed':...      11             6
# 62  [{'layer': '950mb', 'direction': 280, 'speed':...      11             6
# 63  [{'layer': '950mb', 'direction': 280, 'speed':...      11             6
#
#     rh2m  msl_pressure prec_type  prec_amount  snow_depth wind10m_direction  \
# 0      9         -9999      none            0           0               125
# 1     10         -9999      none            0           0               130
# 2     10         -9999      none            1           0               120
# 3     10         -9999      none            1           0               125
# 4     10         -9999      none            1           0               125
# ..   ...           ...       ...          ...         ...               ...
# 59    12          1016      none            4           0               270
# 60    12          1020      none            4           0               280
# 61    12          1018      none            4           0               285
# 62    12          1020      none            4           0               290
# 63    12          1018      none            4           0               290
#
#     wind10m_speed           country
# 0               3  papua new guinea
# 1               3  papua new guinea
# 2               3  papua new guinea
# 3               3  papua new guinea
# 4               3  papua new guinea
# ..            ...               ...
# 59              4               usa
# 60              4               usa
# 61              4               usa
# 62              4               usa
# 63              4               usa
#
# [320 rows x 17 columns]

# %% [markdown]
# Al meter toda la información en un único dataframe tendremos que crear una columna que corresponda con el nombre del país.

# %% [markdown]
# Guardar el dataframe obtenido para usarlo en la siguiente sesión de pair programming.

# %% [markdown]
# 💡 Pistas 💡:
# Crearos un diccionario donde:
# Las keys sean los nombres de los paises
# Los values sean las coordenadas de los paises en formato lista.
# Iterar por el diccionario. Dentro del for haremos la llamada a la API como hemos aprendido en las clases invertidas. Recordamos que para iterar por el diccionario tenemos que seguir la siguiente estructura:
# for key, value in diccionario.items():
#     print(key, value)

# %% [markdown]
# Crearnos un dataframe vacío donde iremos concatenando los datos obtenidos de la API cada país.

# %% [markdown]
# Guardad el csv ya que mañana lo necesitaremos para hacer el ejercicio de pair programming.
# Happy coding 🦈

# %%
df_todo.to_csv('../Datos/clima_paises.csv', index=False)
