# %% [markdown]
# `Pair Programming ETL II transformación`

# %%
from IPython.core.interactiveshell import InteractiveShell # Nos permite mostar más de una salida por celda
InteractiveShell.ast_node_interactivity = "all" # Nos permite mostar más de una salida por celda

import requests
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
pd.options.display.max_columns=None

# %% [markdown]
# El objetivo de la sesión de hoy será juntar en un único csv la información de ambas fuentes. Para ello:
#
# Cargaremos los dos ficheros de datos

# %%
df= pd.read_csv('../Datos/attacks_limpieza_IV.csv', index_col= 0)
df_clima= pd.read_csv('../Datos/clima_paises.csv')

# %% [markdown]
# Del dataframe de los ataques nos quedaremos solo con las filas de los países que seleccionamos en la lección de ayer:
# USA
# Australia
# New Zealand
# South Africa
# Papua New Guinea

# %%
df_paises = df[df.country.isin(['usa', 'australia', 'new zealand', 'south africa', 'papua new guinea'])]

# %%
df_paises['country'].value_counts()
# Out:
# usa                 741
# australia           343
# south africa        234
# new zealand          21
# papua new guinea     16
# Name: country, dtype: int64

# %% [markdown]
# Del dataframe de los datos climáticos seleccionaremos todas las columnas.

# %%
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           9      -9999     -9999     -9999
# 1          6           9      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1  [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m_direction  \
# 0     9         -9999      none            0           0                125
# 1    10         -9999      none            0           0                130
#
#    wind10m_speed           country
# 0              3  papua new guinea
# 1              3  papua new guinea

# %% [markdown]
# Cuando ya tengamos todos los datos deseados juntaremos los dos csv.
#
#     Para hacer esta unión tendremos que hacer un groupby en la tabla de clima para sacar una media de las medidas climáticas por país.
#
#     Antes de hacer el groupby si nos fijamos tenemos dos columnas rh_profile y wind_profile cuya información es una lista de diccionarios. Si intentamos hacer la media de eso no nos dará un valor real. A este problema ya nos enfrentamos en la clase invertida de ETL-2, donde teníais un Bonus para desempaquetar esta información. En caso de que en aquel ejercicio no lo consigierais os dejamos por aquí una posible solución que nos permite separar esa información en distintas columnas. Os dejamos el código documentado.

# %%
df_clima.reset_index()
# Out:
#      index  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0        0          3           9      -9999     -9999     -9999
# 1        1          6           9      -9999     -9999     -9999
# 2        2          9           9      -9999     -9999     -9999
# 3        3         12           9      -9999     -9999     -9999
# 4        4         15           9      -9999     -9999     -9999
# ..     ...        ...         ...        ...       ...       ...
# 315    315        180           2      -9999     -9999     -9999
# 316    316        183           1      -9999     -9999     -9999
# 317    317        186           1      -9999     -9999     -9999
# 318    318        189           1      -9999     -9999     -9999
# 319    319        192           1      -9999     -9999     -9999
#
#                                             rh_profile  \
# 0    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 2    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 3    [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 4    [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# ..                                                 ...
# 315  [{'layer': '950mb', 'rh': 14}, {'layer': '900m...
# 316  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 317  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 318  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 319  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
#
#                                           wind_profile  temp2m  lifted_index  \
# 0    [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1    [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
# 2    [{'layer': '950mb', 'direction': 120, 'speed':...      29            -4
# 3    [{'layer': '950mb', 'direction': 125, 'speed':...      29            -4
# 4    [{'layer': '950mb', 'direction': 120, 'speed':...      28            -4
# ..                                                 ...     ...           ...
# 315  [{'layer': '950mb', 'direction': 265, 'speed':...      10             6
# 316  [{'layer': '950mb', 'direction': 275, 'speed':...      10             6
# 317  [{'layer': '950mb', 'direction': 275, 'speed':...      11             6
# 318  [{'layer': '950mb', 'direction': 280, 'speed':...      11             6
# 319  [{'layer': '950mb', 'direction': 280, 'speed':...      11             6
#
#      rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m_direction  \
# 0       9         -9999      none            0           0                125
# 1      10         -9999      none            0           0                130
# 2      10         -9999      none            1           0                120
# 3      10         -9999      none            1           0                125
# 4      10         -9999      none            1           0                125
# ..    ...           ...       ...          ...         ...                ...
# 315    12          1016      none            4           0                270
# 316    12          1020      none            4           0                280
# 317    12          1018      none            4           0                285
# 318    12          1020      none            4           0                290
# 319    12          1018      none            4           0                290
#
#      wind10m_speed           country
# 0                3  papua new guinea
# 1                3  papua new guinea
# 2                3  papua new guinea
# 3                3  papua new guinea
# 4                3  papua new guinea
# ..             ...               ...
# 315              4               usa
# 316              4               usa
# 317              4               usa
# 318              4               usa
# 319              4               usa
#
# [320 rows x 18 columns]

# %%
df_clima.columns
# Out:
# Index(['timepoint', 'cloudcover', 'highcloud', 'midcloud', 'lowcloud',
#        'rh_profile', 'wind_profile', 'temp2m', 'lifted_index', 'rh2m',
#        'msl_pressure', 'prec_type', 'prec_amount', 'snow_depth',
#        'wind10m_direction', 'wind10m_speed', 'country'],
#       dtype='object')

# %%
df_clima['rh_profile'][0]
df_clima['wind_profile'][0]
# Out:
# "[{'layer': '950mb', 'rh': 12}, {'layer': '900mb', 'rh': 12}, {'layer': '850mb', 'rh': 7}, {'layer': '800mb', 'rh': 5}, {'layer': '750mb', 'rh': 6}, {'layer': '700mb', 'rh': 9}, {'layer': '650mb', 'rh': 4}, {'layer': '600mb', 'rh': -1}, {'layer': '550mb', 'rh': 0}, {'layer': '500mb', 'rh': 3}, {'layer': '450mb', 'rh': 1}, {'layer': '400mb', 'rh': -3}, {'layer': '350mb', 'rh': 0}, {'layer': '300mb', 'rh': -2}, {'layer': '250mb', 'rh': -1}, {'layer': '200mb', 'rh': -1}]"
# "[{'layer': '950mb', 'direction': 125, 'speed': 3}, {'layer': '900mb', 'direction': 130, 'speed': 3}, {'layer': '850mb', 'direction': 120, 'speed': 3}, {'layer': '800mb', 'direction': 105, 'speed': 3}, {'layer': '750mb', 'direction': 100, 'speed': 3}, {'layer': '700mb', 'direction': 95, 'speed': 3}, {'layer': '650mb', 'direction': 90, 'speed': 4}, {'layer': '600mb', 'direction': 85, 'speed': 4}, {'layer': '550mb', 'direction': 85, 'speed': 4}, {'layer': '500mb', 'direction': 80, 'speed': 4}, {'layer': '450mb', 'direction': 100, 'speed': 5}, {'layer': '400mb', 'direction': 100, 'speed': 5}, {'layer': '350mb', 'direction': 95, 'speed': 5}, {'layer': '300mb', 'direction': 90, 'speed': 4}, {'layer': '250mb', 'direction': 105, 'speed': 5}, {'layer': '200mb', 'direction': 85, 'speed': 4}]"

# %%
# os recomendamos resetear el index del dataframe de los datos climáticos para que no se repitan los nombres de las columnas.
# El primer problema al que nos podemos enfrentar es que si vemos los tipos de las columnas vemos que estas columnas son objetos,
#  es decir, strings, lo que hará que trabajar con ellas sea un poco complicado: 

df_clima.dtypes
# Out:
# timepoint             int64
# cloudcover            int64
# highcloud             int64
# midcloud              int64
# lowcloud              int64
# rh_profile           object
# wind_profile         object
# temp2m                int64
# lifted_index          int64
# rh2m                  int64
# msl_pressure          int64
# prec_type            object
# prec_amount           int64
# snow_depth            int64
# wind10m_direction     int64
# wind10m_speed         int64
# country              object
# dtype: object

# %%
# en Python tenemos la librería `ast` que nos permite castear un string que dentro tiene diccionarios, o listas o tuplas a su 
# tipo correspondiente. En nuestro caso, lo que conseguiremos es no tener strings sino listas en la columna. Esto lo haremos
#  de la siguiente forma: 

import ast

df_clima['wind_profile']= df_clima['wind_profile'].apply(ast.literal_eval)

df_clima['rh_profile']= df_clima['rh_profile'].apply(ast.literal_eval)

# %%
df_clima.head(2)
# Out:
#    timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0          3           9      -9999     -9999     -9999
# 1          6           9      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1  [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m_direction  \
# 0     9         -9999      none            0           0                125
# 1    10         -9999      none            0           0                130
#
#    wind10m_speed           country
# 0              3  papua new guinea
# 1              3  papua new guinea

# %%
df_clima['rh_profile'][0]
# Out:
# [{'layer': '950mb', 'rh': 12},
#  {'layer': '900mb', 'rh': 12},
#  {'layer': '850mb', 'rh': 7},
#  {'layer': '800mb', 'rh': 5},
#  {'layer': '750mb', 'rh': 6},
#  {'layer': '700mb', 'rh': 9},
#  {'layer': '650mb', 'rh': 4},
#  {'layer': '600mb', 'rh': -1},
#  {'layer': '550mb', 'rh': 0},
#  {'layer': '500mb', 'rh': 3},
#  {'layer': '450mb', 'rh': 1},
#  {'layer': '400mb', 'rh': -3},
#  {'layer': '350mb', 'rh': 0},
#  {'layer': '300mb', 'rh': -2},
#  {'layer': '250mb', 'rh': -1},
#  {'layer': '200mb', 'rh': -1}]

# %%
df_clima['rh_profile'][1]
# Out:
# [{'layer': '950mb', 'rh': 12},
#  {'layer': '900mb', 'rh': 14},
#  {'layer': '850mb', 'rh': 9},
#  {'layer': '800mb', 'rh': 8},
#  {'layer': '750mb', 'rh': 8},
#  {'layer': '700mb', 'rh': 9},
#  {'layer': '650mb', 'rh': 7},
#  {'layer': '600mb', 'rh': 3},
#  {'layer': '550mb', 'rh': 0},
#  {'layer': '500mb', 'rh': 8},
#  {'layer': '450mb', 'rh': -1},
#  {'layer': '400mb', 'rh': -4},
#  {'layer': '350mb', 'rh': 8},
#  {'layer': '300mb', 'rh': -1},
#  {'layer': '250mb', 'rh': -1},
#  {'layer': '200mb', 'rh': 1}]

# %%
#hay que generar una serie por cada elemento de la lista
rh = df_clima['rh_profile'].apply(pd.Series)  #lo almacenamos por separado para poder trabajar más fácilmente con él
rh.head(2)
# Out:
#                              0                             1   \
# 0  {'layer': '950mb', 'rh': 12}  {'layer': '900mb', 'rh': 12}
# 1  {'layer': '950mb', 'rh': 12}  {'layer': '900mb', 'rh': 14}
#
#                             2                            3   \
# 0  {'layer': '850mb', 'rh': 7}  {'layer': '800mb', 'rh': 5}
# 1  {'layer': '850mb', 'rh': 9}  {'layer': '800mb', 'rh': 8}
#
#                             4                            5   \
# 0  {'layer': '750mb', 'rh': 6}  {'layer': '700mb', 'rh': 9}
# 1  {'layer': '750mb', 'rh': 8}  {'layer': '700mb', 'rh': 9}
#
#                             6                             7   \
# 0  {'layer': '650mb', 'rh': 4}  {'layer': '600mb', 'rh': -1}
# 1  {'layer': '650mb', 'rh': 7}   {'layer': '600mb', 'rh': 3}
#
#                             8                            9   \
# 0  {'layer': '550mb', 'rh': 0}  {'layer': '500mb', 'rh': 3}
# 1  {'layer': '550mb', 'rh': 0}  {'layer': '500mb', 'rh': 8}
#
#                              10                            11  \
# 0   {'layer': '450mb', 'rh': 1}  {'layer': '400mb', 'rh': -3}
# 1  {'layer': '450mb', 'rh': -1}  {'layer': '400mb', 'rh': -4}
#
#                             12                            13  \
# 0  {'layer': '350mb', 'rh': 0}  {'layer': '300mb', 'rh': -2}
# 1  {'layer': '350mb', 'rh': 8}  {'layer': '300mb', 'rh': -1}
#
#                              14                            15
# 0  {'layer': '250mb', 'rh': -1}  {'layer': '200mb', 'rh': -1}
# 1  {'layer': '250mb', 'rh': -1}   {'layer': '200mb', 'rh': 1}

# %%
rh_0=rh[0].apply(pd.Series) #generamos ahora una columna para cada 'key'
rh_0
# Out:
#      layer  rh
# 0    950mb  12
# 1    950mb  12
# 2    950mb  13
# 3    950mb  12
# 4    950mb  13
# ..     ...  ..
# 315  950mb  14
# 316  950mb  13
# 317  950mb  13
# 318  950mb  13
# 319  950mb  12
#
# [320 rows x 2 columns]

# %%
nombre= rh_0['layer'][115]
nombre
# Out:
# '950mb'

# %%
valores= list(rh_0['rh'])
print(valores)
# Out:
# [12, 12, 13, 12, 13, 13, 13, 13, 12, 11, 12, 12, 11, 14, 14, 14, 14, 14, 14, 12, 13, 14, 14, 14, 13, 13, 13, 13, 14, 13, 14, 12, 13, 12, 13, 12, 13, 13, 13, 13, 12, 12, 12, 12, 13, 13, 13, 14, 14, 13, 13, 13, 13, 13, 13, 13, 12, 12, 12, 12, 14, 13, 13, 13, 12, 11, 12, 12, 13, 13, 14, 13, 12, 12, 13, 12, 12, 11, 11, 12, 12, 13, 14, 14, 14, 14, 14, 14, 14, 14, 12, 14, 13, 12, 12, 12, 12, 13, 15, 14, 14, 12, 12, 12, 13, 13, 14, 15, 14, 14, 14, 13, 13, 13, 14, 14, 15, 13, 13, 14, 14, 14, 14, 15, 14, 11, 11, 12, 14, 14, 15, 13, 11, 13, 14, 15, 15, 15, 13, 7, 7, 9, 11, 12, 13, 14, 8, 4, 7, 12, 13, 14, 13, 14, 7, 4, 9, 10, 12, 15, 14, 13, 8, 6, 9, 11, 13, 14, 15, 15, 13, 10, 8, 11, 12, 14, 14, 14, 10, 8, 8, 11, 13, 15, 15, 15, 15, 12, 10, 13, 13, 14, 13, 12, 12, 13, 13, 13, 13, 12, 12, 12, 12, 12, 12, 12, 12, 12, 12, 11, 11, 11, 12, 12, 11, 10, 12, 14, 12, 14, 14, 13, 13, 13, 14, 15, 14, 14, 13, 11, 13, 13, 13, 13, 13, 13, 12, 12, 13, 13, 12, 13, 13, 12, 11, 12, 12, 12, 12, 13, 13, 13, 13, 13, 12, 13, 11, 11, 10, 7, 8, 11, 11, 12, 12, 10, 10, 12, 14, 16, 16, 12, 12, 13, 10, 10, 10, 9, 9, 10, 16, 13, 11, 11, 12, 12, 12, 11, 10, 9, 10, 9, 9, 10, 10, 9, 10, 9, 9, 10, 11, 10, 11, 13, 13, 14, 16, 15, 12, 11, 14, 15, 13, 13, 12, 14, 13, 13, 13, 12]

# %%
nombre_columna = "rh_" + rh_0['layer'][115]
nombre_columna
# Out:
# 'rh_950mb'

# %%
#df_clima.insert(nombre, valores)

# %%
# Ok, hemos conseguido desempaquetar la información de la lista en distintas columnas. Ahora tenemos que despempaquetar la información de los 
# diccionarios en distintas columnas. En este caso, lo que querremos es que las key de los diccionarios sean los nombres de las columnas y los 
# values los valores de las celdas del dataframe. Volveremos a seguir entonces la misma lógica que antes con el apply, pero en este caso necesitamos hacerlo para todo el dataframe (que es x): 

# Por eso empezamos con un for para iterar por cada una de las columnas. 
for i in range(len(rh.columns)): 

    # aplicamos el apply,extraemos el valore de la key "layer" y lo almacenamos en una variable que convertimos a string 
    nombre = "rh_" + str(rh[i].apply(pd.Series)['layer'][0]) 

    # hacemos lo mismo con una variable que se llame valores para "guardar" los valores de la celda
    valores = list(rh[i].apply(pd.Series)["rh"] )

    # usamos el método insert de los dataframes para ir añadiendo esta información a el dataframe con la información del clima. 
    df_clima.insert(i, nombre, valores)

# %%
df_clima.columns
# Out:
# Index(['rh_950mb', 'rh_900mb', 'rh_850mb', 'rh_800mb', 'rh_750mb', 'rh_700mb',
#        'rh_650mb', 'rh_600mb', 'rh_550mb', 'rh_500mb', 'rh_450mb', 'rh_400mb',
#        'rh_350mb', 'rh_300mb', 'rh_250mb', 'rh_200mb', 'timepoint',
#        'cloudcover', 'highcloud', 'midcloud', 'lowcloud', 'rh_profile',
#        'wind_profile', 'temp2m', 'lifted_index', 'rh2m', 'msl_pressure',
#        'prec_type', 'prec_amount', 'snow_depth', 'wind10m_direction',
#        'wind10m_speed', 'country'],
#       dtype='object')

# %%
df_clima.head()
# Out:
#    rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  rh_650mb  \
# 0        12        12         7         5         6         9         4
# 1        12        14         9         8         8         9         7
# 2        13        14        10         8         8         8         8
# 3        12        13        11         9         7         7         8
# 4        13        10         9         5         5         7         8
#
#    rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  rh_350mb  rh_300mb  \
# 0        -1         0         3         1        -3         0        -2
# 1         3         0         8        -1        -4         8        -1
# 2        10         8        11         3        -2         3        -4
# 3         8         8         3         7        -1         4        -3
# 4         8         8         3         6        -2         6        -4
#
#    rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0        -1        -1          3           9      -9999     -9999     -9999
# 1        -1         1          6           9      -9999     -9999     -9999
# 2        -2         5          9           9      -9999     -9999     -9999
# 3        -2         5         12           9      -9999     -9999     -9999
# 4         0        15         15           9      -9999     -9999     -9999
#
#                                           rh_profile  \
# 0  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 2  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
# 3  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 4  [{'layer': '950mb', 'rh': 13}, {'layer': '900m...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1  [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
# 2  [{'layer': '950mb', 'direction': 120, 'speed':...      29            -4
# 3  [{'layer': '950mb', 'direction': 125, 'speed':...      29            -4
# 4  [{'layer': '950mb', 'direction': 120, 'speed':...      28            -4
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m_direction  \
# 0     9         -9999      none            0           0                125
# 1    10         -9999      none            0           0                130
# 2    10         -9999      none            1           0                120
# 3    10         -9999      none            1           0                125
# 4    10         -9999      none            1           0                125
#
#    wind10m_speed           country
# 0              3  papua new guinea
# 1              3  papua new guinea
# 2              3  papua new guinea
# 3              3  papua new guinea
# 4              3  papua new guinea

# %%
# nos creamos un dataframe nuevo con el resultado de la información de una de las columnas separadas por columnas. Esto nos va a devolver un dataframe 
# donde cada fila será una celda del dataframe anterior.

# %%
#hacenos lo mismo para la columna wind
y = df_clima['wind_profile'].apply(pd.Series) 
y[0].apply(pd.Series)['layer'][0]
y
# Out:
# '950mb'
#                                                    0   \
# 0    {'layer': '950mb', 'direction': 125, 'speed': 3}
# 1    {'layer': '950mb', 'direction': 130, 'speed': 3}
# 2    {'layer': '950mb', 'direction': 120, 'speed': 3}
# 3    {'layer': '950mb', 'direction': 125, 'speed': 3}
# 4    {'layer': '950mb', 'direction': 120, 'speed': 3}
# ..                                                ...
# 315  {'layer': '950mb', 'direction': 265, 'speed': 5}
# 316  {'layer': '950mb', 'direction': 275, 'speed': 5}
# 317  {'layer': '950mb', 'direction': 275, 'speed': 5}
# 318  {'layer': '950mb', 'direction': 280, 'speed': 5}
# 319  {'layer': '950mb', 'direction': 280, 'speed': 5}
#
#                                                    1   \
# 0    {'layer': '900mb', 'direction': 130, 'speed': 3}
# 1    {'layer': '900mb', 'direction': 130, 'speed': 3}
# 2    {'layer': '900mb', 'direction': 120, 'speed': 3}
# 3    {'layer': '900mb', 'direction': 125, 'speed': 3}
# 4    {'layer': '900mb', 'direction': 120, 'speed': 3}
# ..                                                ...
# 315  {'layer': '900mb', 'direction': 255, 'speed': 5}
# 316  {'layer': '900mb', 'direction': 260, 'speed': 5}
# 317  {'layer': '900mb', 'direction': 270, 'speed': 5}
# 318  {'layer': '900mb', 'direction': 275, 'speed': 5}
# 319  {'layer': '900mb', 'direction': 275, 'speed': 5}
#
#                                                    2   \
# 0    {'layer': '850mb', 'direction': 120, 'speed': 3}
# 1    {'layer': '850mb', 'direction': 125, 'speed': 3}
# 2    {'layer': '850mb', 'direction': 120, 'speed': 3}
# 3    {'layer': '850mb', 'direction': 125, 'speed': 3}
# 4    {'layer': '850mb', 'direction': 125, 'speed': 3}
# ..                                                ...
# 315  {'layer': '850mb', 'direction': 265, 'speed': 5}
# 316  {'layer': '850mb', 'direction': 260, 'speed': 5}
# 317  {'layer': '850mb', 'direction': 270, 'speed': 5}
# 318  {'layer': '850mb', 'direction': 270, 'speed': 5}
# 319  {'layer': '850mb', 'direction': 275, 'speed': 5}
#
#                                                    3   \
# 0    {'layer': '800mb', 'direction': 105, 'speed': 3}
# 1    {'layer': '800mb', 'direction': 115, 'speed': 3}
# 2    {'layer': '800mb', 'direction': 115, 'speed': 3}
# 3    {'layer': '800mb', 'direction': 120, 'speed': 3}
# 4    {'layer': '800mb', 'direction': 130, 'speed': 4}
# ..                                                ...
# 315  {'layer': '800mb', 'direction': 270, 'speed': 6}
# 316  {'layer': '800mb', 'direction': 265, 'speed': 5}
# 317  {'layer': '800mb', 'direction': 270, 'speed': 5}
# 318  {'layer': '800mb', 'direction': 270, 'speed': 5}
# 319  {'layer': '800mb', 'direction': 275, 'speed': 5}
#
#                                                    4   \
# 0    {'layer': '750mb', 'direction': 100, 'speed': 3}
# 1    {'layer': '750mb', 'direction': 105, 'speed': 3}
# 2    {'layer': '750mb', 'direction': 110, 'speed': 3}
# 3    {'layer': '750mb', 'direction': 120, 'speed': 4}
# 4    {'layer': '750mb', 'direction': 125, 'speed': 4}
# ..                                                ...
# 315  {'layer': '750mb', 'direction': 270, 'speed': 6}
# 316  {'layer': '750mb', 'direction': 265, 'speed': 6}
# 317  {'layer': '750mb', 'direction': 270, 'speed': 5}
# 318  {'layer': '750mb', 'direction': 275, 'speed': 6}
# 319  {'layer': '750mb', 'direction': 275, 'speed': 5}
#
#                                                    5   \
# 0     {'layer': '700mb', 'direction': 95, 'speed': 3}
# 1    {'layer': '700mb', 'direction': 105, 'speed': 3}
# 2    {'layer': '700mb', 'direction': 115, 'speed': 4}
# 3    {'layer': '700mb', 'direction': 115, 'speed': 4}
# 4    {'layer': '700mb', 'direction': 125, 'speed': 4}
# ..                                                ...
# 315  {'layer': '700mb', 'direction': 270, 'speed': 6}
# 316  {'layer': '700mb', 'direction': 265, 'speed': 6}
# 317  {'layer': '700mb', 'direction': 270, 'speed': 6}
# 318  {'layer': '700mb', 'direction': 275, 'speed': 6}
# 319  {'layer': '700mb', 'direction': 275, 'speed': 6}
#
#                                                    6   \
# 0     {'layer': '650mb', 'direction': 90, 'speed': 4}
# 1    {'layer': '650mb', 'direction': 100, 'speed': 3}
# 2    {'layer': '650mb', 'direction': 115, 'speed': 4}
# 3    {'layer': '650mb', 'direction': 110, 'speed': 4}
# 4    {'layer': '650mb', 'direction': 125, 'speed': 4}
# ..                                                ...
# 315  {'layer': '650mb', 'direction': 275, 'speed': 6}
# 316  {'layer': '650mb', 'direction': 270, 'speed': 6}
# 317  {'layer': '650mb', 'direction': 275, 'speed': 6}
# 318  {'layer': '650mb', 'direction': 280, 'speed': 6}
# 319  {'layer': '650mb', 'direction': 275, 'speed': 6}
#
#                                                    7   \
# 0     {'layer': '600mb', 'direction': 85, 'speed': 4}
# 1     {'layer': '600mb', 'direction': 90, 'speed': 3}
# 2    {'layer': '600mb', 'direction': 110, 'speed': 4}
# 3    {'layer': '600mb', 'direction': 105, 'speed': 4}
# 4    {'layer': '600mb', 'direction': 110, 'speed': 4}
# ..                                                ...
# 315  {'layer': '600mb', 'direction': 275, 'speed': 6}
# 316  {'layer': '600mb', 'direction': 275, 'speed': 6}
# 317  {'layer': '600mb', 'direction': 275, 'speed': 6}
# 318  {'layer': '600mb', 'direction': 280, 'speed': 6}
# 319  {'layer': '600mb', 'direction': 275, 'speed': 6}
#
#                                                    8   \
# 0     {'layer': '550mb', 'direction': 85, 'speed': 4}
# 1     {'layer': '550mb', 'direction': 80, 'speed': 4}
# 2     {'layer': '550mb', 'direction': 95, 'speed': 4}
# 3     {'layer': '550mb', 'direction': 95, 'speed': 4}
# 4     {'layer': '550mb', 'direction': 90, 'speed': 4}
# ..                                                ...
# 315  {'layer': '550mb', 'direction': 275, 'speed': 6}
# 316  {'layer': '550mb', 'direction': 275, 'speed': 6}
# 317  {'layer': '550mb', 'direction': 275, 'speed': 6}
# 318  {'layer': '550mb', 'direction': 275, 'speed': 6}
# 319  {'layer': '550mb', 'direction': 275, 'speed': 6}
#
#                                                    9   \
# 0     {'layer': '500mb', 'direction': 80, 'speed': 4}
# 1     {'layer': '500mb', 'direction': 80, 'speed': 4}
# 2     {'layer': '500mb', 'direction': 90, 'speed': 4}
# 3     {'layer': '500mb', 'direction': 90, 'speed': 5}
# 4     {'layer': '500mb', 'direction': 80, 'speed': 5}
# ..                                                ...
# 315  {'layer': '500mb', 'direction': 275, 'speed': 6}
# 316  {'layer': '500mb', 'direction': 275, 'speed': 6}
# 317  {'layer': '500mb', 'direction': 275, 'speed': 6}
# 318  {'layer': '500mb', 'direction': 275, 'speed': 6}
# 319  {'layer': '500mb', 'direction': 275, 'speed': 6}
#
#                                                    10  \
# 0    {'layer': '450mb', 'direction': 100, 'speed': 5}
# 1    {'layer': '450mb', 'direction': 100, 'speed': 5}
# 2     {'layer': '450mb', 'direction': 90, 'speed': 5}
# 3     {'layer': '450mb', 'direction': 90, 'speed': 5}
# 4     {'layer': '450mb', 'direction': 75, 'speed': 5}
# ..                                                ...
# 315  {'layer': '450mb', 'direction': 270, 'speed': 7}
# 316  {'layer': '450mb', 'direction': 270, 'speed': 6}
# 317  {'layer': '450mb', 'direction': 270, 'speed': 6}
# 318  {'layer': '450mb', 'direction': 275, 'speed': 6}
# 319  {'layer': '450mb', 'direction': 270, 'speed': 6}
#
#                                                    11  \
# 0    {'layer': '400mb', 'direction': 100, 'speed': 5}
# 1    {'layer': '400mb', 'direction': 100, 'speed': 5}
# 2    {'layer': '400mb', 'direction': 100, 'speed': 4}
# 3     {'layer': '400mb', 'direction': 90, 'speed': 5}
# 4     {'layer': '400mb', 'direction': 90, 'speed': 5}
# ..                                                ...
# 315  {'layer': '400mb', 'direction': 265, 'speed': 6}
# 316  {'layer': '400mb', 'direction': 260, 'speed': 6}
# 317  {'layer': '400mb', 'direction': 265, 'speed': 5}
# 318  {'layer': '400mb', 'direction': 275, 'speed': 5}
# 319  {'layer': '400mb', 'direction': 275, 'speed': 6}
#
#                                                    12  \
# 0     {'layer': '350mb', 'direction': 95, 'speed': 5}
# 1     {'layer': '350mb', 'direction': 90, 'speed': 4}
# 2     {'layer': '350mb', 'direction': 90, 'speed': 4}
# 3     {'layer': '350mb', 'direction': 80, 'speed': 5}
# 4     {'layer': '350mb', 'direction': 75, 'speed': 5}
# ..                                                ...
# 315  {'layer': '350mb', 'direction': 270, 'speed': 6}
# 316  {'layer': '350mb', 'direction': 245, 'speed': 5}
# 317  {'layer': '350mb', 'direction': 265, 'speed': 5}
# 318  {'layer': '350mb', 'direction': 270, 'speed': 5}
# 319  {'layer': '350mb', 'direction': 275, 'speed': 5}
#
#                                                    13  \
# 0     {'layer': '300mb', 'direction': 90, 'speed': 4}
# 1    {'layer': '300mb', 'direction': 105, 'speed': 4}
# 2    {'layer': '300mb', 'direction': 100, 'speed': 5}
# 3    {'layer': '300mb', 'direction': 105, 'speed': 5}
# 4    {'layer': '300mb', 'direction': 105, 'speed': 5}
# ..                                                ...
# 315  {'layer': '300mb', 'direction': 280, 'speed': 7}
# 316  {'layer': '300mb', 'direction': 250, 'speed': 5}
# 317  {'layer': '300mb', 'direction': 275, 'speed': 4}
# 318  {'layer': '300mb', 'direction': 260, 'speed': 5}
# 319  {'layer': '300mb', 'direction': 265, 'speed': 5}
#
#                                                    14  \
# 0    {'layer': '250mb', 'direction': 105, 'speed': 5}
# 1    {'layer': '250mb', 'direction': 105, 'speed': 5}
# 2     {'layer': '250mb', 'direction': 85, 'speed': 4}
# 3     {'layer': '250mb', 'direction': 90, 'speed': 4}
# 4     {'layer': '250mb', 'direction': 80, 'speed': 4}
# ..                                                ...
# 315  {'layer': '250mb', 'direction': 280, 'speed': 8}
# 316  {'layer': '250mb', 'direction': 270, 'speed': 6}
# 317  {'layer': '250mb', 'direction': 270, 'speed': 6}
# 318  {'layer': '250mb', 'direction': 260, 'speed': 5}
# 319  {'layer': '250mb', 'direction': 260, 'speed': 5}
#
#                                                    15
# 0     {'layer': '200mb', 'direction': 85, 'speed': 4}
# 1     {'layer': '200mb', 'direction': 95, 'speed': 5}
# 2     {'layer': '200mb', 'direction': 90, 'speed': 5}
# 3     {'layer': '200mb', 'direction': 60, 'speed': 4}
# 4     {'layer': '200mb', 'direction': 45, 'speed': 3}
# ..                                                ...
# 315  {'layer': '200mb', 'direction': 280, 'speed': 9}
# 316  {'layer': '200mb', 'direction': 275, 'speed': 8}
# 317  {'layer': '200mb', 'direction': 280, 'speed': 7}
# 318  {'layer': '200mb', 'direction': 280, 'speed': 7}
# 319  {'layer': '200mb', 'direction': 270, 'speed': 7}
#
# [320 rows x 16 columns]

# %%
for i in range(len(y.columns)): 

    # aplicamos el apply,extraemos el valore de la key "layer" y lo almacenamos en una variable que convertimos a string 
    nombre = "wi_speed" + str(y[i].apply(pd.Series)['layer'][0]) 
    valores = list(y[i].apply(pd.Series)["speed"])
    df_clima.insert(i, nombre, valores)
    
    nombre2 = "wi_direction" + str(y[i].apply(pd.Series)['layer'][0]) 
    valores2 = list(y[i].apply(pd.Series)["direction"])
    df_clima.insert(i, nombre2, valores2)

# %%
df_clima.columns
df_clima.shape
# Out:
# Index(['wi_direction950mb', 'wi_direction900mb', 'wi_direction850mb',
#        'wi_direction800mb', 'wi_direction750mb', 'wi_direction700mb',
#        'wi_direction650mb', 'wi_direction600mb', 'wi_direction550mb',
#        'wi_direction500mb', 'wi_direction450mb', 'wi_direction400mb',
#        'wi_direction350mb', 'wi_direction300mb', 'wi_direction250mb',
#        'wi_direction200mb', 'wi_speed200mb', 'wi_speed250mb', 'wi_speed300mb',
#        'wi_speed350mb', 'wi_speed400mb', 'wi_speed450mb', 'wi_speed500mb',
#        'wi_speed550mb', 'wi_speed600mb', 'wi_speed650mb', 'wi_speed700mb',
#        'wi_speed750mb', 'wi_speed800mb', 'wi_speed850mb', 'wi_speed900mb',
#        'wi_speed950mb', 'rh_950mb', 'rh_900mb', 'rh_850mb', 'rh_800mb',
#        'rh_750mb', 'rh_700mb', 'rh_650mb', 'rh_600mb', 'rh_550mb', 'rh_500mb',
#        'rh_450mb', 'rh_400mb', 'rh_350mb', 'rh_300mb', 'rh_250mb', 'rh_200mb',
#        'timepoint', 'cloudcover', 'highcloud', 'midcloud', 'lowcloud',
#        'rh_profile', 'wind_profile', 'temp2m', 'lifted_index', 'rh2m',
#        'msl_pressure', 'prec_type', 'prec_amount', 'snow_depth',
#        'wind10m_direction', 'wind10m_speed', 'country'],
#       dtype='object')
# (320, 65)

# %%
df_clima.head(2)
# Out:
#    wi_direction950mb  wi_direction900mb  wi_direction850mb  wi_direction800mb  \
# 0                125                130                120                105
# 1                130                130                125                115
#
#    wi_direction750mb  wi_direction700mb  wi_direction650mb  wi_direction600mb  \
# 0                100                 95                 90                 85
# 1                105                105                100                 90
#
#    wi_direction550mb  wi_direction500mb  wi_direction450mb  wi_direction400mb  \
# 0                 85                 80                100                100
# 1                 80                 80                100                100
#
#    wi_direction350mb  wi_direction300mb  wi_direction250mb  wi_direction200mb  \
# 0                 95                 90                105                 85
# 1                 90                105                105                 95
#
#    wi_speed200mb  wi_speed250mb  wi_speed300mb  wi_speed350mb  wi_speed400mb  \
# 0              4              5              4              5              5
# 1              5              5              4              4              5
#
#    wi_speed450mb  wi_speed500mb  wi_speed550mb  wi_speed600mb  wi_speed650mb  \
# 0              5              4              4              4              4
# 1              5              4              4              3              3
#
#    wi_speed700mb  wi_speed750mb  wi_speed800mb  wi_speed850mb  wi_speed900mb  \
# 0              3              3              3              3              3
# 1              3              3              3              3              3
#
#    wi_speed950mb  rh_950mb  rh_900mb  rh_850mb  rh_800mb  rh_750mb  rh_700mb  \
# 0              3        12        12         7         5         6         9
# 1              3        12        14         9         8         8         9
#
#    rh_650mb  rh_600mb  rh_550mb  rh_500mb  rh_450mb  rh_400mb  rh_350mb  \
# 0         4        -1         0         3         1        -3         0
# 1         7         3         0         8        -1        -4         8
#
#    rh_300mb  rh_250mb  rh_200mb  timepoint  cloudcover  highcloud  midcloud  \
# 0        -2        -1        -1          3           9      -9999     -9999
# 1        -1        -1         1          6           9      -9999     -9999
#
#    lowcloud                                         rh_profile  \
# 0     -9999  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
# 1     -9999  [{'layer': '950mb', 'rh': 12}, {'layer': '900m...
#
#                                         wind_profile  temp2m  lifted_index  \
# 0  [{'layer': '950mb', 'direction': 125, 'speed':...      28            -1
# 1  [{'layer': '950mb', 'direction': 130, 'speed':...      29            -4
#
#    rh2m  msl_pressure prec_type  prec_amount  snow_depth  wind10m_direction  \
# 0     9         -9999      none            0           0                125
# 1    10         -9999      none            0           0                130
#
#    wind10m_speed           country
# 0              3  papua new guinea
# 1              3  papua new guinea

# %%
df_clima.to_csv('../Datos/datos_clima.csv', index=False)
df_paises.to_csv('../Datos/datos_paises.csv', index=False)

# %%
# una vez que hayamos hecho esto para las dos columnas ya podremos hacer el gropuby para después unir toda la información. 

df_mean = df_clima.groupby("country").mean()
df_mean
# Out:
#                   wi_direction950mb  wi_direction900mb  wi_direction850mb  \
# country
# australia                155.234375         141.093750         150.390625
# new zealand               95.156250          93.593750          92.343750
# papua new guinea         138.437500         144.140625         155.859375
# south africa             262.812500         284.609375         267.187500
# usa                      291.250000         287.343750         285.468750
#
#                   wi_direction800mb  wi_direction750mb  wi_direction700mb  \
# country
# australia                147.500000         142.500000         148.125000
# new zealand               90.546875          89.453125          89.609375
# papua new guinea         155.000000         140.000000         135.468750
# south africa             143.750000          93.281250         102.812500
# usa                      281.484375         279.609375         276.875000
#
#                   wi_direction650mb  wi_direction600mb  wi_direction550mb  \
# country
# australia                124.843750          95.625000          98.515625
# new zealand               90.000000          93.203125          93.046875
# papua new guinea         124.531250         118.125000         112.031250
# south africa             104.765625          99.843750          93.906250
# usa                      274.218750         271.953125         270.234375
#
#                   wi_direction500mb  wi_direction450mb  wi_direction400mb  \
# country
# australia                 96.796875         101.640625          97.265625
# new zealand               94.296875         126.718750         117.890625
# papua new guinea         100.781250          97.109375          95.156250
# south africa              90.937500          88.671875          88.281250
# usa                      268.437500         266.093750         264.531250
#
#                   wi_direction350mb  wi_direction300mb  wi_direction250mb  \
# country
# australia                 93.203125          91.328125          84.687500
# new zealand              152.890625         200.468750         177.343750
# papua new guinea          91.171875          84.609375          86.640625
# south africa              83.828125          88.359375          87.656250
# usa                      263.046875         261.250000         259.375000
#
#                   wi_direction200mb  wi_speed200mb  wi_speed250mb  \
# country
# australia                 73.359375       5.578125       5.171875
# new zealand              242.500000       3.546875       3.203125
# papua new guinea          86.171875       4.687500       4.484375
# south africa              89.531250       3.296875       2.781250
# usa                      261.015625       9.359375       8.953125
#
#                   wi_speed300mb  wi_speed350mb  wi_speed400mb  wi_speed450mb  \
# country
# australia              4.781250       4.390625       4.156250       4.093750
# new zealand            3.031250       3.140625       3.109375       3.062500
# papua new guinea       4.390625       4.140625       4.062500       3.984375
# south africa           3.140625       3.312500       3.406250       3.406250
# usa                    8.171875       7.468750       7.015625       6.578125
#
#                   wi_speed500mb  wi_speed550mb  wi_speed600mb  wi_speed650mb  \
# country
# australia              3.656250       3.406250       3.359375       3.093750
# new zealand            3.312500       3.750000       4.125000       4.125000
# papua new guinea       3.656250       3.421875       3.343750       3.375000
# south africa           3.437500       3.671875       4.000000       3.796875
# usa                    6.234375       6.015625       5.812500       5.656250
#
#                   wi_speed700mb  wi_speed750mb  wi_speed800mb  wi_speed850mb  \
# country
# australia              2.765625       2.687500       2.640625       2.453125
# new zealand            4.031250       4.078125       4.125000       3.906250
# papua new guinea       3.281250       3.203125       3.109375       2.828125
# south africa           3.156250       2.484375       2.218750       2.296875
# usa                    5.531250       5.421875       5.281250       5.078125
#
#                   wi_speed900mb  wi_speed950mb   rh_950mb   rh_900mb  \
# country
# australia              2.375000       2.328125  12.500000  11.765625
# new zealand            3.546875       3.218750  13.046875  12.156250
# papua new guinea       2.828125       2.796875  12.875000  12.703125
# south africa           2.515625       2.187500  11.765625  10.437500
# usa                    4.968750       4.984375  11.500000  12.000000
#
#                    rh_850mb   rh_800mb   rh_750mb   rh_700mb   rh_650mb  \
# country
# australia         10.140625   9.031250   8.531250   8.796875   9.578125
# new zealand        7.937500   5.171875   3.906250   3.359375   3.828125
# papua new guinea  10.093750   8.203125   7.906250   8.515625   8.500000
# south africa      11.000000  11.125000  11.734375  11.593750  11.265625
# usa               10.109375   5.734375   3.968750   3.203125   2.687500
#
#                    rh_600mb   rh_550mb   rh_500mb   rh_450mb   rh_400mb  \
# country
# australia         10.687500   9.734375   8.218750   8.171875   7.453125
# new zealand        4.109375   4.062500   3.718750   3.375000   3.093750
# papua new guinea   8.078125   7.093750   6.812500   4.656250   3.046875
# south africa      11.500000  11.578125  11.515625  10.296875  10.000000
# usa                2.656250   3.312500   4.843750   5.937500   7.015625
#
#                    rh_350mb  rh_300mb   rh_250mb   rh_200mb  timepoint  \
# country
# australia          6.187500  5.875000   7.765625   8.234375       97.5
# new zealand        2.265625  1.968750   2.296875   4.468750       97.5
# papua new guinea   2.859375  3.265625   4.515625   6.671875       97.5
# south africa      10.203125  9.578125  10.953125  10.859375       97.5
# usa                7.718750  8.093750   7.500000   1.734375       97.5
#
#                   cloudcover  highcloud  midcloud  lowcloud     temp2m  \
# country
# australia           6.953125    -9999.0   -9999.0   -9999.0  28.156250
# new zealand         4.953125    -9999.0   -9999.0   -9999.0  27.453125
# papua new guinea    6.062500    -9999.0   -9999.0   -9999.0  28.250000
# south africa        8.609375    -9999.0   -9999.0   -9999.0  23.406250
# usa                 7.515625    -9999.0   -9999.0   -9999.0  10.875000
#
#                   lifted_index       rh2m  msl_pressure  prec_amount  \
# country
# australia            -2.828125   9.890625     -9999.000     4.000000
# new zealand          -1.093750  10.515625     -9999.000     2.546875
# papua new guinea     -3.406250  10.093750     -9999.000     3.312500
# south africa         -2.234375  12.578125     -9999.000     4.484375
# usa                   7.015625  11.796875      1021.125     2.734375
#
#                   snow_depth  wind10m_direction  wind10m_speed
# country
# australia                0.0         170.781250       2.312500
# new zealand              0.0          94.765625       3.031250
# papua new guinea         0.0         142.500000       2.765625
# south africa             0.0         259.531250       2.000000
# usa                      0.0         296.796875       3.953125

# %%
df_final = pd.merge(left = df_paises, right= df_mean, how= "left", left_on= "country", right_on= "country")
df_final
# Out:
#       year        type       country                   area  \
# 0     2018     Boating           usa             California
# 1     2018  Unprovoked           usa                Florida
# 2     2018    Provoked     australia             Queensland
# 3     2018  Unprovoked     australia      Western Australia
# 4     2018  Unprovoked  south africa  Western Cape Province
# ...    ...         ...           ...                    ...
# 1350  1997  Unprovoked     australia                    NaN
# 1351  1997  Unprovoked     australia        New South Wales
# 1352  1997  Unprovoked     australia      Western Australia
# 1353  1997  Unprovoked     australia      Western Australia
# 1354  1997  Unprovoked           usa         North Carolina
#
#                             location        activity                   name  \
# 0        Oceanside, San Diego County        Paddling            Julie Wolfe
# 1       Cocoa Beach, Brevard  County         Walking              Cody High
# 2                    Cairns Aquarium  Feeding sharks                   male
# 3            Surfers Point, Prevelly         Surfing              Rob Bruce
# 4     Robberg Beach, Plettenberg Bay   Paddle-skiing                   male
# ...                              ...             ...                    ...
# 1350                             NaN         Fishing              fisherman
# 1351                                        Swimming               Arab boy
# 1352                     Roebuck Bay          Diving                   male
# 1353                             NaN    Pearl diving                  Ahmun
# 1354                  Ocracoke Inlet        Swimming  Coast Guard personnel
#
#          time             species        siglo  \
# 0       18h00         White shark  siglo - XXI
# 1       17h00      Bull shark, 6'  siglo - XXI
# 2     Morning     Grey reef shark  siglo - XXI
# 3       09h30           3 m shark  siglo - XXI
# 4       09h40  White shark, 2.5 m  siglo - XXI
# ...       ...                 ...          ...
# 1350   Unknow                 NaN       Unknow
# 1351   Unknow                 NaN       Unknow
# 1352   Unknow                 NaN       Unknow
# 1353   Unknow                 NaN       Unknow
# 1354   Unknow                 NaN       Unknow
#
#                                                  injury     mes fatal genero  \
# 0     No injury to occupant, outrigger canoe and pad...     Jun     N      F
# 1                                 Lower left leg bitten     May     N      M
# 2     Minor bite to hand by captive shark. PROVOKED ...     May     N      M
# 3                 No injury, knocked off board by shark     Apr     N      M
# 4                      No injury, shark bit hole in ski     Apr     N      M
# ...                                                 ...     ...   ...    ...
# 1350                                              FATAL  Unknow     Y      M
# 1351                                              FATAL  Unknow     Y      F
# 1352                                              FATAL  Unknow     Y      M
# 1353                                              FATAL  Unknow     Y      M
# 1354                                              FATAL  Unknow     Y      M
#
#      categorias_tiburones  edades  wi_direction950mb  wi_direction900mb  \
# 0                   White   57.00         291.250000         287.343750
# 1                    Bull   15.00         291.250000         287.343750
# 2                    Grey   32.00         155.234375         141.093750
# 3                  Unknow   60.00         155.234375         141.093750
# 4                   White   33.00         262.812500         284.609375
# ...                   ...     ...                ...                ...
# 1350               Unknow   27.89         155.234375         141.093750
# 1351               Unknow   27.89         155.234375         141.093750
# 1352               Unknow   27.89         155.234375         141.093750
# 1353               Unknow   27.89         155.234375         141.093750
# 1354               Unknow   27.89         291.250000         287.343750
#
#       wi_direction850mb  wi_direction800mb  wi_direction750mb  \
# 0            285.468750         281.484375         279.609375
# 1            285.468750         281.484375         279.609375
# 2            150.390625         147.500000         142.500000
# 3            150.390625         147.500000         142.500000
# 4            267.187500         143.750000          93.281250
# ...                 ...                ...                ...
# 1350         150.390625         147.500000         142.500000
# 1351         150.390625         147.500000         142.500000
# 1352         150.390625         147.500000         142.500000
# 1353         150.390625         147.500000         142.500000
# 1354         285.468750         281.484375         279.609375
#
#       wi_direction700mb  wi_direction650mb  wi_direction600mb  \
# 0              276.8750         274.218750         271.953125
# 1              276.8750         274.218750         271.953125
# 2              148.1250         124.843750          95.625000
# 3              148.1250         124.843750          95.625000
# 4              102.8125         104.765625          99.843750
# ...                 ...                ...                ...
# 1350           148.1250         124.843750          95.625000
# 1351           148.1250         124.843750          95.625000
# 1352           148.1250         124.843750          95.625000
# 1353           148.1250         124.843750          95.625000
# 1354           276.8750         274.218750         271.953125
#
#       wi_direction550mb  wi_direction500mb  wi_direction450mb  \
# 0            270.234375         268.437500         266.093750
# 1            270.234375         268.437500         266.093750
# 2             98.515625          96.796875         101.640625
# 3             98.515625          96.796875         101.640625
# 4             93.906250          90.937500          88.671875
# ...                 ...                ...                ...
# 1350          98.515625          96.796875         101.640625
# 1351          98.515625          96.796875         101.640625
# 1352          98.515625          96.796875         101.640625
# 1353          98.515625          96.796875         101.640625
# 1354         270.234375         268.437500         266.093750
#
#       wi_direction400mb  wi_direction350mb  wi_direction300mb  \
# 0            264.531250         263.046875         261.250000
# 1            264.531250         263.046875         261.250000
# 2             97.265625          93.203125          91.328125
# 3             97.265625          93.203125          91.328125
# 4             88.281250          83.828125          88.359375
# ...                 ...                ...                ...
# 1350          97.265625          93.203125          91.328125
# 1351          97.265625          93.203125          91.328125
# 1352          97.265625          93.203125          91.328125
# 1353          97.265625          93.203125          91.328125
# 1354         264.531250         263.046875         261.250000
#
#       wi_direction250mb  wi_direction200mb  wi_speed200mb  wi_speed250mb  \
# 0             259.37500         261.015625       9.359375       8.953125
# 1             259.37500         261.015625       9.359375       8.953125
# 2              84.68750          73.359375       5.578125       5.171875
# 3              84.68750          73.359375       5.578125       5.171875
# 4              87.65625          89.531250       3.296875       2.781250
# ...                 ...                ...            ...            ...
# 1350           84.68750          73.359375       5.578125       5.171875
# 1351           84.68750          73.359375       5.578125       5.171875
# 1352           84.68750          73.359375       5.578125       5.171875
# 1353           84.68750          73.359375       5.578125       5.171875
# 1354          259.37500         261.015625       9.359375       8.953125
#
#       wi_speed300mb  wi_speed350mb  wi_speed400mb  wi_speed450mb  \
# 0          8.171875       7.468750       7.015625       6.578125
# 1          8.171875       7.468750       7.015625       6.578125
# 2          4.781250       4.390625       4.156250       4.093750
# 3          4.781250       4.390625       4.156250       4.093750
# 4          3.140625       3.312500       3.406250       3.406250
# ...             ...            ...            ...            ...
# 1350       4.781250       4.390625       4.156250       4.093750
# 1351       4.781250       4.390625       4.156250       4.093750
# 1352       4.781250       4.390625       4.156250       4.093750
# 1353       4.781250       4.390625       4.156250       4.093750
# 1354       8.171875       7.468750       7.015625       6.578125
#
#       wi_speed500mb  wi_speed550mb  wi_speed600mb  wi_speed650mb  \
# 0          6.234375       6.015625       5.812500       5.656250
# 1          6.234375       6.015625       5.812500       5.656250
# 2          3.656250       3.406250       3.359375       3.093750
# 3          3.656250       3.406250       3.359375       3.093750
# 4          3.437500       3.671875       4.000000       3.796875
# ...             ...            ...            ...            ...
# 1350       3.656250       3.406250       3.359375       3.093750
# 1351       3.656250       3.406250       3.359375       3.093750
# 1352       3.656250       3.406250       3.359375       3.093750
# 1353       3.656250       3.406250       3.359375       3.093750
# 1354       6.234375       6.015625       5.812500       5.656250
#
#       wi_speed700mb  wi_speed750mb  wi_speed800mb  wi_speed850mb  \
# 0          5.531250       5.421875       5.281250       5.078125
# 1          5.531250       5.421875       5.281250       5.078125
# 2          2.765625       2.687500       2.640625       2.453125
# 3          2.765625       2.687500       2.640625       2.453125
# 4          3.156250       2.484375       2.218750       2.296875
# ...             ...            ...            ...            ...
# 1350       2.765625       2.687500       2.640625       2.453125
# 1351       2.765625       2.687500       2.640625       2.453125
# 1352       2.765625       2.687500       2.640625       2.453125
# 1353       2.765625       2.687500       2.640625       2.453125
# 1354       5.531250       5.421875       5.281250       5.078125
#
#       wi_speed900mb  wi_speed950mb   rh_950mb   rh_900mb   rh_850mb  \
# 0          4.968750       4.984375  11.500000  12.000000  10.109375
# 1          4.968750       4.984375  11.500000  12.000000  10.109375
# 2          2.375000       2.328125  12.500000  11.765625  10.140625
# 3          2.375000       2.328125  12.500000  11.765625  10.140625
# 4          2.515625       2.187500  11.765625  10.437500  11.000000
# ...             ...            ...        ...        ...        ...
# 1350       2.375000       2.328125  12.500000  11.765625  10.140625
# 1351       2.375000       2.328125  12.500000  11.765625  10.140625
# 1352       2.375000       2.328125  12.500000  11.765625  10.140625
# 1353       2.375000       2.328125  12.500000  11.765625  10.140625
# 1354       4.968750       4.984375  11.500000  12.000000  10.109375
#
#        rh_800mb   rh_750mb   rh_700mb   rh_650mb  rh_600mb   rh_550mb  \
# 0      5.734375   3.968750   3.203125   2.687500   2.65625   3.312500
# 1      5.734375   3.968750   3.203125   2.687500   2.65625   3.312500
# 2      9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 3      9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 4     11.125000  11.734375  11.593750  11.265625  11.50000  11.578125
# ...         ...        ...        ...        ...       ...        ...
# 1350   9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 1351   9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 1352   9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 1353   9.031250   8.531250   8.796875   9.578125  10.68750   9.734375
# 1354   5.734375   3.968750   3.203125   2.687500   2.65625   3.312500
#
#        rh_500mb   rh_450mb   rh_400mb   rh_350mb  rh_300mb   rh_250mb  \
# 0      4.843750   5.937500   7.015625   7.718750  8.093750   7.500000
# 1      4.843750   5.937500   7.015625   7.718750  8.093750   7.500000
# 2      8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 3      8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 4     11.515625  10.296875  10.000000  10.203125  9.578125  10.953125
# ...         ...        ...        ...        ...       ...        ...
# 1350   8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 1351   8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 1352   8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 1353   8.218750   8.171875   7.453125   6.187500  5.875000   7.765625
# 1354   4.843750   5.937500   7.015625   7.718750  8.093750   7.500000
#
#        rh_200mb  timepoint  cloudcover  highcloud  midcloud  lowcloud  \
# 0      1.734375       97.5    7.515625    -9999.0   -9999.0   -9999.0
# 1      1.734375       97.5    7.515625    -9999.0   -9999.0   -9999.0
# 2      8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 3      8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 4     10.859375       97.5    8.609375    -9999.0   -9999.0   -9999.0
# ...         ...        ...         ...        ...       ...       ...
# 1350   8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 1351   8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 1352   8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 1353   8.234375       97.5    6.953125    -9999.0   -9999.0   -9999.0
# 1354   1.734375       97.5    7.515625    -9999.0   -9999.0   -9999.0
#
#         temp2m  lifted_index       rh2m  msl_pressure  prec_amount  \
# 0     10.87500      7.015625  11.796875      1021.125     2.734375
# 1     10.87500      7.015625  11.796875      1021.125     2.734375
# 2     28.15625     -2.828125   9.890625     -9999.000     4.000000
# 3     28.15625     -2.828125   9.890625     -9999.000     4.000000
# 4     23.40625     -2.234375  12.578125     -9999.000     4.484375
# ...        ...           ...        ...           ...          ...
# 1350  28.15625     -2.828125   9.890625     -9999.000     4.000000
# 1351  28.15625     -2.828125   9.890625     -9999.000     4.000000
# 1352  28.15625     -2.828125   9.890625     -9999.000     4.000000
# 1353  28.15625     -2.828125   9.890625     -9999.000     4.000000
# 1354  10.87500      7.015625  11.796875      1021.125     2.734375
#
#       snow_depth  wind10m_direction  wind10m_speed
# 0            0.0         296.796875       3.953125
# 1            0.0         296.796875       3.953125
# 2            0.0         170.781250       2.312500
# 3            0.0         170.781250       2.312500
# 4            0.0         259.531250       2.000000
# ...          ...                ...            ...
# 1350         0.0         170.781250       2.312500
# 1351         0.0         170.781250       2.312500
# 1352         0.0         170.781250       2.312500
# 1353         0.0         170.781250       2.312500
# 1354         0.0         296.796875       3.953125
#
# [1355 rows x 77 columns]

# %% [markdown]
# Guardar los resultados obtenidos en un csv que usaremos en próximos ejercicios de pair programming.
# Happy coding 🦈

# %%
df_final.to_csv('../Datos/etl_transformacion.csv', index=False)
